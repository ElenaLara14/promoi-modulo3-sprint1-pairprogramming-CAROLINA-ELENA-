# %% [markdown]
# ### Debes crear un nuevo DataFrame que combine la información de ambos conjuntos de datos en un solo conjunto de datos. Para hacerlo, debes seleccionar el método de unión de Pandas que consideres más apropiado para esta situación y justificar por qué crees que ese método es el mejor en tu informe.
#
# Asegúrate de realizar los siguientes pasos:
#
# 1. Explora y carga ambos conjuntos de datos en pandas DataFrames.
#
# 2. Identifica las columnas comunes entre los dos conjuntos de datos.
#
# 3. Utiliza el método de unión de Pandas que consideres más adecuado para combinar los datos de ambos años en un solo DataFrame.
#
# 4. Explica por qué elegiste ese método de unión y cómo se llevaron a cabo los pasos anteriores.
#
# ## Ejercicios de Limpieza
# Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.
#
# Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#
# No tengan espacios.
#
# Estén en minúscula.
#
# No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#
# Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#
# Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.
#
# La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.
#
# Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.
#
# Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$".
#
# Guarda el DataFrame para usarlo en el pairprogramming de mañana.
#
# ## Ejercicios de Filtrado
# Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.
#
# Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.
#
# Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.
#
# Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.
#
# Encuentra los países cuyatasa de fertilidad sea mayor a 6.
#
# Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.
#
# Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70.

# %%
# nuestras librerias a utilizar
import pandas as pd
import numpy as np


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df1 = pd.read_csv("world-data-2023_part1.csv", index_col=0)
df1.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
df2 = pd.read_csv("world-data-2023_part2.csv", index_col=0)
df2.head()
# Out:
#                  GDP Gross primary education enrollment (%)  \
# 0   $19,101,353,833                                 104.00%
# 1   $15,278,077,447                                 107.00%
# 2  $169,988,236,398                                 109.90%
# 3    $3,154,057,987                                 106.40%
# 4   $94,635,415,870                                 113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population      country  \
# 0            11.12%        9,797,273  Afghanistan
# 1            12.33%        1,747,593      Albania
# 2            11.70%       31,510,100      Algeria
# 3               NaN           67,873      Andorra
# 4             6.89%       21,061,025       Angola
#
#                     coordinates
# 0    ('33.93911 ', '67.709953')
# 1   ('41.153332 ', '20.168331')
# 2    ('28.033886 ', '1.659626')
# 3    ('42.506285 ', '1.521801')
# 4  ('-11.202692 ', '17.873887')

# %%
df2.shape
# Out:
# (195, 19)

# %%
#creando el mergeado_inner
df_union = df1.merge(df2, how='inner',left_on='Country', right_on = "country")
df_union.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price                GDP  \
# 0            4.47             2.10%         $0.70    $19,101,353,833
# 1            1.62            28.10%         $1.36    $15,278,077,447
# 2            3.02             0.80%         $0.28   $169,988,236,398
# 3            1.27            34.00%         $1.51     $3,154,057,987
# 4            5.52            46.30%         $0.97    $94,635,415,870
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
# 2                                109.90%
# 3                                106.40%
# 4                                113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population      country  \
# 0            11.12%        9,797,273  Afghanistan
# 1            12.33%        1,747,593      Albania
# 2            11.70%       31,510,100      Algeria
# 3               NaN           67,873      Andorra
# 4             6.89%       21,061,025       Angola
#
#                     coordinates
# 0    ('33.93911 ', '67.709953')
# 1   ('41.153332 ', '20.168331')
# 2    ('28.033886 ', '1.659626')
# 3    ('42.506285 ', '1.521801')
# 4  ('-11.202692 ', '17.873887')

# %%
df_union.shape # Hemos elegido merge para unir ambos DF para mantener las columnas de ambos mediante la columna union Country.
# Out:
# (195, 35)

# %%
# LIMPIEZA - eliminar columna country
df_union.drop(["country"], axis=1, inplace=True)

# %%
df_union.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price                GDP  \
# 0            4.47             2.10%         $0.70    $19,101,353,833
# 1            1.62            28.10%         $1.36    $15,278,077,447
# 2            3.02             0.80%         $0.28   $169,988,236,398
# 3            1.27            34.00%         $1.51     $3,154,057,987
# 4            5.52            46.30%         $0.97    $94,635,415,870
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
# 2                                109.90%
# 3                                106.40%
# 4                                113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population                   coordinates
# 0            11.12%        9,797,273    ('33.93911 ', '67.709953')
# 1            12.33%        1,747,593   ('41.153332 ', '20.168331')
# 2            11.70%       31,510,100    ('28.033886 ', '1.659626')
# 3               NaN           67,873    ('42.506285 ', '1.521801')
# 4             6.89%       21,061,025  ('-11.202692 ', '17.873887')

# %%
nuevas_columnas = {columna:columna.lower().replace(" ","") for columna in df_union}

df_union.rename(columns= nuevas_columnas, inplace=True)

# %%
df_union.head()
# Out:
#        country density\n(p/km2) abbreviation agriculturalland(%)  \
# 0  Afghanistan               60           AF              58.10%
# 1      Albania              105           AL              43.10%
# 2      Algeria               18           DZ              17.40%
# 3      Andorra              164           AD              40.00%
# 4       Angola               26           AO              47.50%
#
#   landarea(km2) armedforcessize  birthrate  callingcode capital/majorcity  \
# 0       652,230         323,000      32.49         93.0             Kabul
# 1        28,748           9,000      11.78        355.0            Tirana
# 2     2,381,741         317,000      24.28        213.0           Algiers
# 3           468             NaN       7.20        376.0  Andorra la Vella
# 4     1,246,700         117,000      40.73        244.0            Luanda
#
#   co2-emissions     cpi cpichange(%) currency-code  fertilityrate  \
# 0         8,672   149.9        2.30%           AFN           4.47
# 1         4,536  119.05        1.40%           ALL           1.62
# 2       150,006  151.36        2.00%           DZD           3.02
# 3           469     NaN          NaN           EUR           1.27
# 4        34,693  261.73       17.10%           AOA           5.52
#
#   forestedarea(%) gasolineprice                gdp  \
# 0           2.10%        $0.70    $19,101,353,833
# 1          28.10%        $1.36    $15,278,077,447
# 2           0.80%        $0.28   $169,988,236,398
# 3          34.00%        $1.51     $3,154,057,987
# 4          46.30%        $0.97    $94,635,415,870
#
#   grossprimaryeducationenrollment(%) grosstertiaryeducationenrollment(%)  \
# 0                            104.00%                               9.70%
# 1                            107.00%                              55.00%
# 2                            109.90%                              51.40%
# 3                            106.40%                                 NaN
# 4                            113.50%                               9.30%
#
#    infantmortality       largestcity  lifeexpectancy  maternalmortalityratio  \
# 0             47.9             Kabul            64.5                   638.0
# 1              7.8            Tirana            78.5                    15.0
# 2             20.1           Algiers            76.7                   112.0
# 3              2.7  Andorra la Vella             NaN                     NaN
# 4             51.6            Luanda            60.8                   241.0
#
#   minimumwage officiallanguage outofpockethealthexpenditure  \
# 0      $0.43            Pashto                       78.40%
# 1      $1.12          Albanian                       56.90%
# 2      $0.95            Arabic                       28.10%
# 3      $6.63           Catalan                       36.40%
# 4      $0.71        Portuguese                       33.40%
#
#    physiciansperthousand  population population:laborforceparticipation(%)  \
# 0                   0.28  38,041,754                                48.90%
# 1                   1.20   2,854,191                                55.70%
# 2                   1.72  43,053,054                                41.20%
# 3                   3.33      77,142                                   NaN
# 4                   0.21  31,825,295                                77.50%
#
#   taxrevenue(%) totaltaxrate unemploymentrate urban_population  \
# 0         9.30%       71.40%           11.12%        9,797,273
# 1        18.60%       36.60%           12.33%        1,747,593
# 2        37.20%       66.10%           11.70%       31,510,100
# 3           NaN          NaN              NaN           67,873
# 4         9.20%       49.10%            6.89%       21,061,025
#
#                     coordinates
# 0    ('33.93911 ', '67.709953')
# 1   ('41.153332 ', '20.168331')
# 2    ('28.033886 ', '1.659626')
# 3    ('42.506285 ', '1.521801')
# 4  ('-11.202692 ', '17.873887')

# %%
patron = "\(*\)"
df_union["density\n"] = df_union["density\n(p/km2)"].str.contains("\(*\)")

# %%
df_union.head()
# Out:
#        country density\n(p/km2) abbreviation agriculturalland(%)  \
# 0  Afghanistan               60           AF              58.10%
# 1      Albania              105           AL              43.10%
# 2      Algeria               18           DZ              17.40%
# 3      Andorra              164           AD              40.00%
# 4       Angola               26           AO              47.50%
#
#   landarea(km2) armedforcessize  birthrate  callingcode capital/majorcity  \
# 0       652,230         323,000      32.49         93.0             Kabul
# 1        28,748           9,000      11.78        355.0            Tirana
# 2     2,381,741         317,000      24.28        213.0           Algiers
# 3           468             NaN       7.20        376.0  Andorra la Vella
# 4     1,246,700         117,000      40.73        244.0            Luanda
#
#   co2-emissions     cpi cpichange(%) currency-code  fertilityrate  \
# 0         8,672   149.9        2.30%           AFN           4.47
# 1         4,536  119.05        1.40%           ALL           1.62
# 2       150,006  151.36        2.00%           DZD           3.02
# 3           469     NaN          NaN           EUR           1.27
# 4        34,693  261.73       17.10%           AOA           5.52
#
#   forestedarea(%) gasolineprice                gdp  \
# 0           2.10%        $0.70    $19,101,353,833
# 1          28.10%        $1.36    $15,278,077,447
# 2           0.80%        $0.28   $169,988,236,398
# 3          34.00%        $1.51     $3,154,057,987
# 4          46.30%        $0.97    $94,635,415,870
#
#   grossprimaryeducationenrollment(%) grosstertiaryeducationenrollment(%)  \
# 0                            104.00%                               9.70%
# 1                            107.00%                              55.00%
# 2                            109.90%                              51.40%
# 3                            106.40%                                 NaN
# 4                            113.50%                               9.30%
#
#    infantmortality       largestcity  lifeexpectancy  maternalmortalityratio  \
# 0             47.9             Kabul            64.5                   638.0
# 1              7.8            Tirana            78.5                    15.0
# 2             20.1           Algiers            76.7                   112.0
# 3              2.7  Andorra la Vella             NaN                     NaN
# 4             51.6            Luanda            60.8                   241.0
#
#   minimumwage officiallanguage outofpockethealthexpenditure  \
# 0      $0.43            Pashto                       78.40%
# 1      $1.12          Albanian                       56.90%
# 2      $0.95            Arabic                       28.10%
# 3      $6.63           Catalan                       36.40%
# 4      $0.71        Portuguese                       33.40%
#
#    physiciansperthousand  population population:laborforceparticipation(%)  \
# 0                   0.28  38,041,754                                48.90%
# 1                   1.20   2,854,191                                55.70%
# 2                   1.72  43,053,054                                41.20%
# 3                   3.33      77,142                                   NaN
# 4                   0.21  31,825,295                                77.50%
#
#   taxrevenue(%) totaltaxrate unemploymentrate urban_population  \
# 0         9.30%       71.40%           11.12%        9,797,273
# 1        18.60%       36.60%           12.33%        1,747,593
# 2        37.20%       66.10%           11.70%       31,510,100
# 3           NaN          NaN              NaN           67,873
# 4         9.20%       49.10%            6.89%       21,061,025
#
#                     coordinates  density\n
# 0    ('33.93911 ', '67.709953')      False
# 1   ('41.153332 ', '20.168331')      False
# 2    ('28.033886 ', '1.659626')      False
# 3    ('42.506285 ', '1.521801')      False
# 4  ('-11.202692 ', '17.873887')      False

# %%
# Renombrar todas las columnas que coinciden con los patrones
df_union.columns = df_union.columns.str.replace(r'\(p/km2\)|\(km2\)', '', regex=True)

# %%
df_union.head()
# Out:
#        country  density\n abbreviation agriculturalland(%)   landarea  \
# 0  Afghanistan         60           AF              58.10%    652,230
# 1      Albania        105           AL              43.10%     28,748
# 2      Algeria         18           DZ              17.40%  2,381,741
# 3      Andorra        164           AD              40.00%        468
# 4       Angola         26           AO              47.50%  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange(%) currency-code  fertilityrate forestedarea(%)  \
# 0   149.9        2.30%           AFN           4.47           2.10%
# 1  119.05        1.40%           ALL           1.62          28.10%
# 2  151.36        2.00%           DZD           3.02           0.80%
# 3     NaN          NaN           EUR           1.27          34.00%
# 4  261.73       17.10%           AOA           5.52          46.30%
#
#   gasolineprice                gdp grossprimaryeducationenrollment(%)  \
# 0        $0.70    $19,101,353,833                             104.00%
# 1        $1.36    $15,278,077,447                             107.00%
# 2        $0.28   $169,988,236,398                             109.90%
# 3        $1.51     $3,154,057,987                             106.40%
# 4        $0.97    $94,635,415,870                             113.50%
#
#   grosstertiaryeducationenrollment(%)  infantmortality       largestcity  \
# 0                               9.70%             47.9             Kabul
# 1                              55.00%              7.8            Tirana
# 2                              51.40%             20.1           Algiers
# 3                                 NaN              2.7  Andorra la Vella
# 4                               9.30%             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0            64.5                   638.0      $0.43            Pashto
# 1            78.5                    15.0      $1.12          Albanian
# 2            76.7                   112.0      $0.95            Arabic
# 3             NaN                     NaN      $6.63           Catalan
# 4            60.8                   241.0      $0.71        Portuguese
#
#   outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                       78.40%                   0.28  38,041,754
# 1                       56.90%                   1.20   2,854,191
# 2                       28.10%                   1.72  43,053,054
# 3                       36.40%                   3.33      77,142
# 4                       33.40%                   0.21  31,825,295
#
#   population:laborforceparticipation(%) taxrevenue(%) totaltaxrate  \
# 0                                48.90%         9.30%       71.40%
# 1                                55.70%        18.60%       36.60%
# 2                                41.20%        37.20%       66.10%
# 3                                   NaN           NaN          NaN
# 4                                77.50%         9.20%       49.10%
#
#   unemploymentrate urban_population                   coordinates  density\n
# 0           11.12%        9,797,273    ('33.93911 ', '67.709953')      False
# 1           12.33%        1,747,593   ('41.153332 ', '20.168331')      False
# 2           11.70%       31,510,100    ('28.033886 ', '1.659626')      False
# 3              NaN           67,873    ('42.506285 ', '1.521801')      False
# 4            6.89%       21,061,025  ('-11.202692 ', '17.873887')      False

# %%
# Renombrar todas las columnas que coinciden con los patrones
df_union.columns = df_union.columns.str.replace(r'\(%\)', '', regex=True)

# %%
df_union.head()
# Out:
#        country  density\n abbreviation agriculturalland   landarea  \
# 0  Afghanistan         60           AF           58.10%    652,230
# 1      Albania        105           AL           43.10%     28,748
# 2      Algeria         18           DZ           17.40%  2,381,741
# 3      Andorra        164           AD           40.00%        468
# 4       Angola         26           AO           47.50%  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# 0   149.9     2.30%           AFN           4.47        2.10%        $0.70
# 1  119.05     1.40%           ALL           1.62       28.10%        $1.36
# 2  151.36     2.00%           DZD           3.02        0.80%        $0.28
# 3     NaN       NaN           EUR           1.27       34.00%        $1.51
# 4  261.73    17.10%           AOA           5.52       46.30%        $0.97
#
#                  gdp grossprimaryeducationenrollment  \
# 0   $19,101,353,833                          104.00%
# 1   $15,278,077,447                          107.00%
# 2  $169,988,236,398                          109.90%
# 3    $3,154,057,987                          106.40%
# 4   $94,635,415,870                          113.50%
#
#   grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                            9.70%             47.9             Kabul
# 1                           55.00%              7.8            Tirana
# 2                           51.40%             20.1           Algiers
# 3                              NaN              2.7  Andorra la Vella
# 4                            9.30%             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0            64.5                   638.0      $0.43            Pashto
# 1            78.5                    15.0      $1.12          Albanian
# 2            76.7                   112.0      $0.95            Arabic
# 3             NaN                     NaN      $6.63           Catalan
# 4            60.8                   241.0      $0.71        Portuguese
#
#   outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                       78.40%                   0.28  38,041,754
# 1                       56.90%                   1.20   2,854,191
# 2                       28.10%                   1.72  43,053,054
# 3                       36.40%                   3.33      77,142
# 4                       33.40%                   0.21  31,825,295
#
#   population:laborforceparticipation taxrevenue totaltaxrate unemploymentrate  \
# 0                             48.90%      9.30%       71.40%           11.12%
# 1                             55.70%     18.60%       36.60%           12.33%
# 2                             41.20%     37.20%       66.10%           11.70%
# 3                                NaN        NaN          NaN              NaN
# 4                             77.50%      9.20%       49.10%            6.89%
#
#   urban_population                   coordinates  density\n
# 0        9,797,273    ('33.93911 ', '67.709953')      False
# 1        1,747,593   ('41.153332 ', '20.168331')      False
# 2       31,510,100    ('28.033886 ', '1.659626')      False
# 3           67,873    ('42.506285 ', '1.521801')      False
# 4       21,061,025  ('-11.202692 ', '17.873887')      False

# %%
nuevas_columnas2 = {columna:columna.replace("\n","").replace(":","") for columna in df_union}

df_union.rename(columns= nuevas_columnas2, inplace=True)

# %%
df_union.head()
# Out:
#        country  density abbreviation agriculturalland   landarea  \
# 0  Afghanistan       60           AF           58.10%    652,230
# 1      Albania      105           AL           43.10%     28,748
# 2      Algeria       18           DZ           17.40%  2,381,741
# 3      Andorra      164           AD           40.00%        468
# 4       Angola       26           AO           47.50%  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# 0   149.9     2.30%           AFN           4.47        2.10%        $0.70
# 1  119.05     1.40%           ALL           1.62       28.10%        $1.36
# 2  151.36     2.00%           DZD           3.02        0.80%        $0.28
# 3     NaN       NaN           EUR           1.27       34.00%        $1.51
# 4  261.73    17.10%           AOA           5.52       46.30%        $0.97
#
#                  gdp grossprimaryeducationenrollment  \
# 0   $19,101,353,833                          104.00%
# 1   $15,278,077,447                          107.00%
# 2  $169,988,236,398                          109.90%
# 3    $3,154,057,987                          106.40%
# 4   $94,635,415,870                          113.50%
#
#   grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                            9.70%             47.9             Kabul
# 1                           55.00%              7.8            Tirana
# 2                           51.40%             20.1           Algiers
# 3                              NaN              2.7  Andorra la Vella
# 4                            9.30%             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0            64.5                   638.0      $0.43            Pashto
# 1            78.5                    15.0      $1.12          Albanian
# 2            76.7                   112.0      $0.95            Arabic
# 3             NaN                     NaN      $6.63           Catalan
# 4            60.8                   241.0      $0.71        Portuguese
#
#   outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                       78.40%                   0.28  38,041,754
# 1                       56.90%                   1.20   2,854,191
# 2                       28.10%                   1.72  43,053,054
# 3                       36.40%                   3.33      77,142
# 4                       33.40%                   0.21  31,825,295
#
#   populationlaborforceparticipation taxrevenue totaltaxrate unemploymentrate  \
# 0                            48.90%      9.30%       71.40%           11.12%
# 1                            55.70%     18.60%       36.60%           12.33%
# 2                            41.20%     37.20%       66.10%           11.70%
# 3                               NaN        NaN          NaN              NaN
# 4                            77.50%      9.20%       49.10%            6.89%
#
#   urban_population                   coordinates  density
# 0        9,797,273    ('33.93911 ', '67.709953')    False
# 1        1,747,593   ('41.153332 ', '20.168331')    False
# 2       31,510,100    ('28.033886 ', '1.659626')    False
# 3           67,873    ('42.506285 ', '1.521801')    False
# 4       21,061,025  ('-11.202692 ', '17.873887')    False

# %%
# La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.

df_modificado = df_union["coordinates"].str.split(",",expand=True)

# %%
df_modificado.columns = ['latitud', 'longitud']

# %%
# Añade las nuevas columnas al DataFrame original
df_union = pd.concat([df_union, df_modificado], axis=1)

# Elimina la columna original coordinates
df_union = df_union.drop(columns=['coordinates'])

# %%
df_union.head()
# Out:
#        country  density abbreviation agriculturalland   landarea  \
# 0  Afghanistan       60           AF           58.10%    652,230
# 1      Albania      105           AL           43.10%     28,748
# 2      Algeria       18           DZ           17.40%  2,381,741
# 3      Andorra      164           AD           40.00%        468
# 4       Angola       26           AO           47.50%  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# 0   149.9     2.30%           AFN           4.47        2.10%        $0.70
# 1  119.05     1.40%           ALL           1.62       28.10%        $1.36
# 2  151.36     2.00%           DZD           3.02        0.80%        $0.28
# 3     NaN       NaN           EUR           1.27       34.00%        $1.51
# 4  261.73    17.10%           AOA           5.52       46.30%        $0.97
#
#                  gdp grossprimaryeducationenrollment  \
# 0   $19,101,353,833                          104.00%
# 1   $15,278,077,447                          107.00%
# 2  $169,988,236,398                          109.90%
# 3    $3,154,057,987                          106.40%
# 4   $94,635,415,870                          113.50%
#
#   grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                            9.70%             47.9             Kabul
# 1                           55.00%              7.8            Tirana
# 2                           51.40%             20.1           Algiers
# 3                              NaN              2.7  Andorra la Vella
# 4                            9.30%             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0            64.5                   638.0      $0.43            Pashto
# 1            78.5                    15.0      $1.12          Albanian
# 2            76.7                   112.0      $0.95            Arabic
# 3             NaN                     NaN      $6.63           Catalan
# 4            60.8                   241.0      $0.71        Portuguese
#
#   outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                       78.40%                   0.28  38,041,754
# 1                       56.90%                   1.20   2,854,191
# 2                       28.10%                   1.72  43,053,054
# 3                       36.40%                   3.33      77,142
# 4                       33.40%                   0.21  31,825,295
#
#   populationlaborforceparticipation taxrevenue totaltaxrate unemploymentrate  \
# 0                            48.90%      9.30%       71.40%           11.12%
# 1                            55.70%     18.60%       36.60%           12.33%
# 2                            41.20%     37.20%       66.10%           11.70%
# 3                               NaN        NaN          NaN              NaN
# 4                            77.50%      9.20%       49.10%            6.89%
#
#   urban_population  density         latitud       longitud
# 0        9,797,273    False    ('33.93911 '   '67.709953')
# 1        1,747,593    False   ('41.153332 '   '20.168331')
# 2       31,510,100    False   ('28.033886 '    '1.659626')
# 3           67,873    False   ('42.506285 '    '1.521801')
# 4       21,061,025    False  ('-11.202692 '   '17.873887')

# %%
# Eliminar signos de dólar y convertir las columnas a tipo numérico
df_union['gasolineprice'] = df_union['gasolineprice'].replace('[\$,]', '', regex=True)
df_union['gdp'] = df_union['gdp'].replace('[\$,]', '', regex=True).replace(',', '', regex=True)
df_union['minimumwage'] = df_union['minimumwage'].replace('[\$,]', '', regex=True)

# %%
df_union.head()
# Out:
#        country  density abbreviation agriculturalland   landarea  \
# 0  Afghanistan       60           AF           58.10%    652,230
# 1      Albania      105           AL           43.10%     28,748
# 2      Algeria       18           DZ           17.40%  2,381,741
# 3      Andorra      164           AD           40.00%        468
# 4       Angola       26           AO           47.50%  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# 0   149.9     2.30%           AFN           4.47        2.10%         0.70
# 1  119.05     1.40%           ALL           1.62       28.10%         1.36
# 2  151.36     2.00%           DZD           3.02        0.80%         0.28
# 3     NaN       NaN           EUR           1.27       34.00%         1.51
# 4  261.73    17.10%           AOA           5.52       46.30%         0.97
#
#              gdp grossprimaryeducationenrollment  \
# 0   19101353833                          104.00%
# 1   15278077447                          107.00%
# 2  169988236398                          109.90%
# 3    3154057987                          106.40%
# 4   94635415870                          113.50%
#
#   grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 0                            9.70%             47.9             Kabul
# 1                           55.00%              7.8            Tirana
# 2                           51.40%             20.1           Algiers
# 3                              NaN              2.7  Andorra la Vella
# 4                            9.30%             51.6            Luanda
#
#    lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0            64.5                   638.0       0.43            Pashto
# 1            78.5                    15.0       1.12          Albanian
# 2            76.7                   112.0       0.95            Arabic
# 3             NaN                     NaN       6.63           Catalan
# 4            60.8                   241.0       0.71        Portuguese
#
#   outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                       78.40%                   0.28  38,041,754
# 1                       56.90%                   1.20   2,854,191
# 2                       28.10%                   1.72  43,053,054
# 3                       36.40%                   3.33      77,142
# 4                       33.40%                   0.21  31,825,295
#
#   populationlaborforceparticipation taxrevenue totaltaxrate unemploymentrate  \
# 0                            48.90%      9.30%       71.40%           11.12%
# 1                            55.70%     18.60%       36.60%           12.33%
# 2                            41.20%     37.20%       66.10%           11.70%
# 3                               NaN        NaN          NaN              NaN
# 4                            77.50%      9.20%       49.10%            6.89%
#
#   urban_population  density         latitud       longitud
# 0        9,797,273    False    ('33.93911 '   '67.709953')
# 1        1,747,593    False   ('41.153332 '   '20.168331')
# 2       31,510,100    False   ('28.033886 '    '1.659626')
# 3           67,873    False   ('42.506285 '    '1.521801')
# 4       21,061,025    False  ('-11.202692 '   '17.873887')

# %%
df_union.to_csv("ejercicios_pair_union.csv",index=False)

# %% [markdown]
# ## Ejercicios de Filtrado
# Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.
#
# Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.
#
# Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.
#
# Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.
#
# Encuentra los países cuyatasa de fertilidad sea mayor a 6.
#
# Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.
#
# Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70.

# %%
paises_filtrados = df_union[(df_union['infantmortality'] >= 40) & (df_union['infantmortality'] <= 50)]

print(paises_filtrados)
# Out:
#           country  density abbreviation agriculturalland   landarea  \
# 0     Afghanistan       60           AF           58.10%    652,230
# 26   Burkina Faso       76           BF           44.20%    274,200
# 27        Burundi      463           BI           79.20%     27,830
# 47       Djibouti       43           DJ           73.40%     23,200
# 72          Haiti      414           HT           66.80%     27,750
# 89       Kiribati      147           KI           42.00%        811
# 125         Niger       19           NE           36.10%  1,267,000
# 166         Sudan       25           SD           28.70%  1,861,484
# 175          Togo      152           TG           70.20%     56,785
# 192         Yemen       56           YE           44.60%    527,968
# 193        Zambia       25           ZM           32.10%    752,618
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0           323,000      32.49         93.0             Kabul         8,672
# 26           11,000      37.93        226.0       Ouagadougou         3,418
# 27           31,000      39.01        257.0         Bujumbura           495
# 47           13,000      21.47        253.0     Djibouti City           620
# 72                0      24.35        509.0    Port-au-Prince         2,978
# 89              NaN      27.89        686.0      South Tarawa            66
# 125          10,000      46.08        227.0            Niamey         2,017
# 166         124,000      32.18        249.0          Khartoum        20,000
# 175          10,000      33.11        228.0              Lom�         3,000
# 192          40,000      30.45        967.0             Sanaa        10,609
# 193          16,000      36.19        260.0            Lusaka         5,141
#
#           cpi cpichange currency-code  fertilityrate forestedarea  \
# 0       149.9     2.30%           AFN           4.47        2.10%
# 26     106.58    -3.20%           XOF           5.19       19.30%
# 27     182.11    -0.70%           BIF           5.41       10.90%
# 47     120.25     3.30%           DJF           2.73        0.20%
# 72     179.29    12.50%           HTG           2.94        3.50%
# 89      99.55     0.60%           AUD           3.57       15.00%
# 125    109.32    -2.50%           XOF           6.91        0.90%
# 166  1,344.19    51.00%           SDG           4.41        8.10%
# 175     113.3     0.70%           XOF           4.32        3.10%
# 192    157.58     8.10%           YER           3.79        1.00%
# 193    212.31     9.20%           ZMW           4.63       65.20%
#
#     gasolineprice           gdp grossprimaryeducationenrollment  \
# 0           0.70   19101353833                          104.00%
# 26          0.98   15745810235                           96.10%
# 27          1.21    3012334882                          121.40%
# 47          1.32    3318716359                           75.30%
# 72          0.81    8498981821                          113.60%
# 89            NaN    194647202                          101.30%
# 125         0.88   12928145120                           74.70%
# 166         0.95   18902284476                           76.80%
# 175         0.71    5459979417                          123.80%
# 192         0.92   26914402224                           93.60%
# 193         1.40   23064722446                           98.70%
#
#     grosstertiaryeducationenrollment  infantmortality     largestcity  \
# 0                              9.70%             47.9           Kabul
# 26                             6.50%             49.0     Ouagadougou
# 27                             6.10%             41.0       Bujumbura
# 47                             5.30%             49.8   Djibouti City
# 72                             1.10%             49.5  Port-au-Prince
# 89                               NaN             41.2    South Tarawa
# 125                            4.40%             48.0          Niamey
# 166                           16.90%             42.1        Omdurman
# 175                           14.50%             47.4            Lom�
# 192                           10.20%             42.9           Sanaa
# 193                            4.10%             40.4          Lusaka
#
#      lifeexpectancy  maternalmortalityratio minimumwage officiallanguage  \
# 0              64.5                   638.0       0.43            Pashto
# 26             61.2                   320.0       0.34            French
# 27             61.2                   548.0         NaN          Kirundi
# 47             66.6                   248.0         NaN           French
# 72             63.7                   480.0       0.25            French
# 89             68.1                    92.0         NaN          English
# 125            62.0                   509.0       0.29            French
# 166            65.1                   295.0       0.41            Arabic
# 175            60.8                   396.0       0.34            French
# 192            66.1                   164.0         NaN           Arabic
# 193            63.5                   213.0       0.24           English
#
#     outofpockethealthexpenditure  physiciansperthousand  population  \
# 0                         78.40%                   0.28  38,041,754
# 26                        36.10%                   0.08  20,321,378
# 27                        19.10%                   0.10  11,530,580
# 47                        20.40%                   0.22     973,560
# 72                        36.30%                   0.23  11,263,077
# 89                         0.20%                   0.20     117,606
# 125                       52.30%                   0.04  23,310,715
# 166                       63.20%                   0.26  42,813,238
# 175                       51.00%                   0.08   8,082,366
# 192                       81.00%                   0.31  29,161,922
# 193                       27.50%                   1.19  17,861,030
#
#     populationlaborforceparticipation taxrevenue totaltaxrate  \
# 0                              48.90%      9.30%       71.40%
# 26                             66.40%     15.00%       41.30%
# 27                             79.20%     13.60%       41.20%
# 47                             60.20%        NaN       37.90%
# 72                             67.20%        NaN       42.70%
# 89                                NaN     22.00%       32.70%
# 125                            72.00%     11.80%       47.20%
# 166                            48.40%      8.00%       45.40%
# 175                            77.60%     16.90%       48.20%
# 192                            38.00%        NaN       26.60%
# 193                            74.60%     16.20%       15.60%
#
#     unemploymentrate urban_population  density         latitud  \
# 0             11.12%        9,797,273    False    ('33.93911 '
# 26             6.26%        6,092,349    False   ('12.238333 '
# 27             1.43%        1,541,177    False   ('-3.373056 '
# 47            10.30%          758,549    False   ('11.825138 '
# 72            13.78%        6,328,948    False   ('18.971187 '
# 89               NaN           64,489    False   ('1.8368976 '
# 125            0.47%        3,850,231    False   ('17.607789 '
# 166           16.53%       14,957,233    False   ('12.862807 '
# 175            2.04%        3,414,638    False    ('8.619543 '
# 192           12.91%       10,869,523    False   ('15.552727 '
# 193           11.43%        7,871,713    False  ('-13.133897 '
#
#              longitud
# 0        '67.709953')
# 26       '-1.561593')
# 27       '29.918886')
# 47       '42.590275')
# 72      '-72.285215')
# 89    '-157.3768317')
# 125       '8.081666')
# 166      '30.217636')
# 175       '0.824782')
# 192      '48.516388')
# 193      '27.849332')
