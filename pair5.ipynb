# %% [markdown]
# Ejercicios apply
#
# 1. Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas.
# 2. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.
# 3. Crea una función para añadir una nueva columna llamada 'Continent' al DataFrame para indicar a qué continente pertenece cada país.
# Guarda el DataFrame después de los cambios creados después de los dos ejercicios anteriores para usarlo en el pairprogramming de mañana.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("world_data_full.csv")
df
# Out:
#      Unnamed: 0      country density abbreviation  agricultural_land  \
# 0             0  Afghanistan      60           AF               58.1
# 1             1      Albania     105           AL               43.1
# 2             2      Algeria      18           DZ               17.4
# 3             3      Andorra     164           AD               40.0
# 4             4       Angola      26           AO               47.5
# ..          ...          ...     ...          ...                ...
# 190         190    Venezuela      32           VE               24.5
# 191         191      Vietnam     314           VN               39.3
# 192         192        Yemen      56           YE               44.6
# 193         193       Zambia      25           ZM               32.1
# 194         194     Zimbabwe      38           ZW               41.9
#
#      land_area armed_forces_size  birth_rate  calling_code capital/major_city  \
# ...

# %%
def cambiar_comas(cadena):
    """
    Reemplaza las comas por puntos en una cadena dada que representa un número decimal
    en formato internacional (con comas como separador de miles y punto como separador decimal).
    Args:
        cadena (str): Una cadena que representa el número decimal en formato 
                      internacional.
    Returns:
        float: El número decimal equivalente en formato de número flotante.
    Note:
        Si ocurre algún error durante el proceso de reemplazo (por ejemplo, si el 
        argumento no es una cadena), la función devolverá np.nan (valor Not a Number) 
        para indicar un valor inválido o no disponible.
    """
    try:
        # Reemplazar las comas por puntos en la cadena
        return float(cadena.replace(",", "."))
    
    except:
        # Si ocurre algún error (por ejemplo, si el argumento no es una cadena),
        # devolver np.nan (valor Not a Number) para indicar un valor inválido o no disponible.
        return np.nan

# %%
# aplicamos de nuevo la función y sobreescribimos los resultados de nuestra función en la misma columna
# land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi 

df["cland_area"] = df["land_area"].apply(cambiar_comas)
df["armed_forces_size"] = df["armed_forces_size"].apply(cambiar_comas)
df["co2-emissions"] = df["co2-emissions"].apply(cambiar_comas)
df["gdp"] = df["gdp"].apply(cambiar_comas)
df["population"] = df["population"].apply(cambiar_comas)
# ya tenemos las comas cambiadas para la columna 'conspriceidx', por lo que podríamos esperar que esta columna ya sea de tipo númerico. Comprobémoslo en la siguiente celda. 
df.head()
# Out:
#    Unnamed: 0      country density abbreviation  agricultural_land  land_area  \
# 0           0  Afghanistan      60           AF               58.1    652,230
# 1           1      Albania     105           AL               43.1     28,748
# 2           2      Algeria      18           DZ               17.4  2,381,741
# 3           3      Andorra     164           AD               40.0        468
# 4           4       Angola      26           AO               47.5  1,246,700
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  ...  \
# 0                NaN       32.49          93.0              Kabul  ...
# 1                NaN       11.78         355.0             Tirana  ...
# 2                NaN       24.28         213.0            Algiers  ...
# 3                NaN        7.20         376.0   Andorra la Vella  ...
# 4                NaN       40.73         244.0             Luanda  ...
#
# ...

# %%
df["population"].dtype
# Out:
# dtype('float64')

# %%
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
def add_continent_column(df, country_column, new_column, mapping):
     df[new_column] = df[country_column].map(mapping)
     add_continent_column(df, 'Country', 'Continent', country_to_continent)


    return df

# %%
df.to_csv("ej_apply.csv")

# %% [markdown]
# Ejercicios groupby
# 1. ¿Cuál es la densidad de población promedio por continente?
# 2. ¿Cuál es la esperanza de vida promedio por idioma oficial? Agrupa los países por idioma oficial y calcula la esperanza de vida promedio.
# 3. ¿Cuál es la tasa de mortalidad infantil promedio por moneda?
# 4. ¿Cuál es el salario mínimo por continente?
# 5. ¿Cuál es la tasa de impuestos total máxima por densidad de población por continente? Para solucionar este ejercicio puedes:
#     - Primero, necesitas calcular la tasa de impuestos total para cada continente. La tasa de impuestos total se encuentra en la columna "total_tax_rate".
#     - Luego, calcula la densidad de población para cada continente. La densidad de población se encuentra en la columna "density".
#     - Ahora, divide la tasa de impuestos total entre la densidad de población para obtener la tasa de impuestos total por persona por kilómetro cuadrado.
#     - Encuentra el país que tiene el valor más alto en esta nueva columna calculada.

# %%
#2.
df.groupby(['country', 'official_language'])['life_expectancy'].mean()
# Out:
# country      official_language
# Afghanistan  Pashto               64.5
# Albania      Albanian             78.5
# Algeria      Arabic               76.7
# Andorra      Catalan               NaN
# Angola       Portuguese           60.8
#                                   ...
# Venezuela    Spanish              72.1
# Vietnam      Vietnamese           75.3
# Yemen        Arabic               66.1
# Zambia       English              63.5
# Zimbabwe     Shona                61.2
# Name: life_expectancy, Length: 190, dtype: float64

# %%
#3
df.groupby('infant_mortality')['currency-code'].median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
#4
